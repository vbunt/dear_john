# %% [markdown]
# В этой программе я разделяю корпус сообщений на отрезки длиной в месяц и с помощью tf-idf нахожу слова, значимые для каждого месяца.

# %%
import sqlite3
from datetime import date as d
from datetime import timedelta
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from collections import Counter
import pandas
# Out:
# /home/valeria/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
conn = sqlite3.connect('oleg.db')
cur = conn.cursor()

# %%
cur.execute('''
select date, GROUP_CONCAT(no_stopwords, ' ')
from meta
join texts on texts.id = meta.id
group by date''')

texts = cur.fetchall()

# %%
cdd = {texts[i][0]:texts[i][1] for i in range(len(texts))}

# %%
first = d.fromisoformat('2018-02-09')
last = d.fromisoformat('2021-02-21')
day = timedelta(days=1)
week = timedelta(days=7)

now = first
while now <= last:
    if str(now) not in cdd.keys():
        cdd[str(now)] = ''
    now += day

# %% [markdown]
# Сделаем словарь, ключами в котором будут месяцы, а значениями - строки с сообщениями.

# %%
current = first
da = {}

while current <= last-day*30:
    articles = ''
    for i in range(30):
        articles = articles + cdd[d.isoformat(current + day*i)] + ' '
    da[d.isoformat(current)] = articles
    current += day*30
    

l = current
articles = ''
while current <= last:
    articles = articles + cdd[d.isoformat(current)] + ' '
    current += day
da[d.isoformat(l)] = articles

# %% [markdown]
# Сколько получилось кусочков:

# %%
len(da)
# Out:
# 37

# %% [markdown]
# ## Модель

# %%
def get_top_tf_idf_words(tfidf_vector, feature_names, top_n):
    sorted_nzs = np.argsort(tfidf_vector.data)[:-(top_n+1):-1]
    return feature_names[tfidf_vector.indices[sorted_nzs]]

# %%
tfidf = TfidfVectorizer(analyzer="word", 
                        stop_words=['то', 'ага', 'ладно', 'короче', 'олег', 
                                    'лера', 'наверное', 'кстати', 'что'])

# %%
articles_tfidf = tfidf.fit_transform(da.values())

# %% [markdown]
# Будем сохранять 7 самых важных слов для каждого кусочка.

# %%
feature_names = np.array(tfidf.get_feature_names())
idf_words = []
long = {}
i = 0
for key in da.keys():
    article = da[key]
    article_vector = articles_tfidf[i, :]
    words = get_top_tf_idf_words(article_vector, feature_names, 7)
    idf_words.extend(words)
    long[key] = words
    i+=1

# %% [markdown]
# Здесь можно обрезать слова по частотности: оставить только те, которые важны сразу для нескольких кусочков. Для визуализации этих данных в презентации я решила вручную выбрать самые интересные, даже если они встречаются только один раз.

# %%
def make_short(idf_words, long, n):
    cnt = Counter(idf_words).most_common()
    big_words = []
    for el in cnt:
        if el[1] >= n:
            big_words.append(el[0])
    
    short = {}
    
    for key in long.keys():
        short[key] = []
        for word in long[key]:
            if word in big_words:
                short[key].append(word)

    return short, big_words

# %%
for_pr = make_short(idf_words, long, 1)[0]

# %% [markdown]
# ## Таблица

# %% [markdown]
# Это моя попытка автоматической визуализации, весьма неудачная. Здесь будут только те слова, которые важны минимум для трех текстов.

# %%
short3, big_words = make_short(idf_words, long, 3)
dates = short3.keys()

# %%
df = pandas.DataFrame({word:[0 for el in dates] for word in big_words})
df.index = dates
df = df.transpose()

# %%
for word in big_words:
    for date in dates:
        if word in short3[date]:
            df.at[word, date] = 1

# %%
def color_reds(value):
    if value == 1:
        color = 'pink'
    else:
        color = 'white'
    return 'background-color: %s' % color

# %%
df.style.applymap(color_reds)
# Out:
# <style  type="text/css" >
#     #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col0 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col1 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col2 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col3 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col4 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col5 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col6 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col7 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col8 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col9 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col10 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col11 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col12 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col13 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col14 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col15 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col16 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col17 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col18 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col19 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col20 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col21 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col22 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col23 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col24 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col25 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col26 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col27 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col28 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col29 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col30 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col31 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col32 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col33 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col34 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col35 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow0_col36 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col0 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col1 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col2 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col3 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col4 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col5 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col6 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col7 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col8 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col9 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col10 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col11 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col12 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col13 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col14 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col15 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col16 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col17 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col18 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col19 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col20 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col21 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col22 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col23 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col24 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col25 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col26 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col27 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col28 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col29 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col30 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col31 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col32 {
#             background-color:  pink;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col33 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col34 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col35 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow1_col36 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow2_col0 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow2_col1 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow2_col2 {
#             background-color:  white;
#         }    #T_32591e5a_d124_11eb_abb5_d0abd512706erow2_col3 {
#             background-color:  pink;
